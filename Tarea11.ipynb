# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisNavarro93/IngenieriaYacimientosGas/blob/main/Tarea11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ![VLE_PREOS.pdf.png](data:image/png;base64,...)
